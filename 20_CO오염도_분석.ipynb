# %%
import pandas as pd

co_1 = pd.read_csv('../data_chaeyeon/20년도_1월_CO오염도_최종.csv')
co_2 = pd.read_csv('../data_chaeyeon/20년도_2월_CO오염도_최종.csv')
co_3 = pd.read_csv('../data_chaeyeon/20년도_3월_CO오염도_최종.csv')
co_4 = pd.read_csv('../data_chaeyeon/20년도_4월_CO오염도_최종.csv')
co_5 = pd.read_csv('../data_chaeyeon/20년도_5월_CO오염도_최종.csv')
co_6 = pd.read_csv('../data_chaeyeon/20년도_6월_CO오염도_최종.csv')
co_7 = pd.read_csv('../data_chaeyeon/20년도_7월_CO오염도_최종.csv')
co_8 = pd.read_csv('../data_chaeyeon/20년도_8월_CO오염도_최종.csv')
co_9 = pd.read_csv('../data_chaeyeon/20년도_9월_CO오염도_최종.csv')
co_10 = pd.read_csv('../data_chaeyeon/20년도_10월_CO오염도_최종.csv')
co_11 = pd.read_csv('../data_chaeyeon/20년도_11월_CO오염도_최종.csv')
co_12 = pd.read_csv('../data_chaeyeon/20년도_12월_CO오염도_최종.csv')

co_1_seoul = co_1.iloc[0:25, :]
co_1_seoul['시.도'] = co_1_seoul['시.도'] + co_1_seoul['시군구']
co_1


# co_2_seoul = co_2.loc[0:25, :]
# co_2_seoul['시.도'] = co_2_seoul['시.도'] + co_2_seoul['시군구']

# co_3_seoul = co_3.loc[0:25, :]
# co_3_seoul['시.도'] = co_3_seoul['시.도'] + co_3_seoul['시군구']

# co_4_seoul = co_4.loc[0:25, :]
# co_4_seoul['시.도'] = co_4_seoul['시.도'] + co_4_seoul['시군구']

# co_5_seoul = co_5.loc[0:25, :]
# co_5_seoul['시.도'] = co_5_seoul['시.도'] + co_5_seoul['시군구']

# co_6_seoul = co_6.loc[0:25, :]
# co_6_seoul['시.도'] = co_6_seoul['시.도'] + co_6_seoul['시군구']

# co_7_seoul = co_7.loc[0:25, :]
# co_7_seoul['시.도'] = co_7_seoul['시.도'] + co_7_seoul['시군구']

# co_8_seoul = co_8.loc[0:25, :]
# co_8_seoul['시.도'] = co_8_seoul['시.도'] + co_8_seoul['시군구']

# co_9_seoul = co_9.loc[0:25, :]
# co_9_seoul['시.도'] = co_9_seoul['시.도'] + co_9_seoul['시군구']

# co_10_seoul = co_10.loc[0:25, :]
# co_10_seoul['시.도'] = co_10_seoul['시.도'] + co_10_seoul['시군구']

# co_11_seoul = co_11.loc[0:25, :]
# co_11_seoul['시.도'] = co_11_seoul['시.도'] + co_11_seoul['시군구']

# co_12_seoul = co_12.loc[0:25, :]
# co_12_seoul['시.도'] = co_12_seoul['시.도'] + co_12_seoul['시군구']
# Out:
# <ipython-input-51-0218e9a14a9f>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_1_seoul['시.도'] = co_1_seoul['시.도'] + co_1_seoul['시군구']
#     Unnamed: 0     시.도   시군구  월평균\n(ppm)
# 0            0    서울중구    중구    0.700000
# 1            1   서울종로구   종로구    0.700000
# 2            2   서울중랑구   중랑구    0.700000
# 3            3  서울동대문구  동대문구    0.600000
# 4            4   서울은평구   은평구    0.800000
# 5            5   서울마포구   마포구    0.500000
# 6            6  서울영등포구  영등포구    0.900000
# 7            7   서울동작구   동작구    0.600000
# 8            8   서울관악구   관악구    0.700000
# 9            9   서울강남구   강남구    0.700000
# 10          10   서울금천구   금천구    0.700000
# 11          11   서울강동구   강동구    0.600000
# 12          12   서울강북구   강북구    0.600000
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import platform
import matplotlib
import numpy as np

if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')
elif platform.system() == 'Darwin': # Mac
    matplotlib.rc('font', family='AppleGothic')
else: #linux
    matplotlib.rc('font', family='NanumGothic')

co_1.plot(x='시.도', y='월평균\n(ppm)', kind='bar',figsize=(10,10) )
plt.title('2020년 1월 지역별 일산화탄소 오염도 수치')
plt.xlabel('지역')
plt.ylabel('수치')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
